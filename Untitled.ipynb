# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression 
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("house_prices_dataset.csv")
df.head()
# Out:
#    square_feet  num_rooms  age  distance_to_city(km)          price
# 0  2248.357077          3   92             22.997972  200374.090410
# 1  1930.867849          2   22             13.984254  268784.847337
# 2  2323.844269          6   33             21.500945  315020.857676
# 3  2761.514928          3   63             10.343638  355111.468459
# 4  1882.923313          7   54             25.485200  234197.123903

# %%
df.describe().T
# Out:
#                         count           mean           std           min  \
# square_feet           10000.0    1999.147496    501.021194    500.000000
# num_rooms             10000.0       4.495100      1.711160      2.000000
# age                   10000.0      49.516900     28.992336      0.000000
# distance_to_city(km)  10000.0      15.362148      8.325101      1.000161
# price                 10000.0  263011.571609  98336.945117 -95613.138249
#
#                                 25%            50%            75%  \
# square_feet             1663.704735    1998.702512    2335.540444
# num_rooms                  3.000000       4.000000       6.000000
# age                       24.000000      49.000000      75.000000
# distance_to_city(km)       8.121636      15.403146      22.447530
# price                 196791.510684  262497.361236  330445.581908
#
#                                 max
# square_feet             3963.118853
# num_rooms                  7.000000
# age                       99.000000
# distance_to_city(km)      29.993892
# price                 660168.255648

# %%
y=df["price"]
X=df.drop(columns="price")

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=33)

# %%
colscal=X.columns

# %%
scalerPipe=Pipeline([
    ("scale",StandardScaler())
])

# %%
preprocess=ColumnTransformer(transformers=[
    ("scaleCol",scalerPipe,colscal)
])

# %%
mainPipe=Pipeline(
    [("preprocess",preprocess),
    ("estimator",LinearRegression())]
)

# %%
model=mainPipe.fit(xtrain,ytrain)
model
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('scaleCol',
#                                                   Pipeline(steps=[('scale',
#                                                                    StandardScaler())]),
#                                                   Index(['square_feet', 'num_rooms', 'age', 'distance_to_city(km)'], dtype='object'))])),
#                 ('estimator', LinearRegression())])

# %%
ypred=model.predict(xtest)

# %%
mse= mean_squared_error(ytest,ypred)
np.sqrt(mse)
# Out:
# 20192.31549396703

# %%
r2=r2_score(ytest,ypred)
r2
# Out:
# 0.9562371528722248

# %%
mae=mean_absolute_error(ytest,ypred)
mae
# Out:
# 16172.27047661626

# %%
ytrain_pred=model.predict(xtrain)
residual=ytrain - ytrain_pred
residual
# Out:
# 7998     4092.406917
# 3584   -16520.676249
# 4295    25712.014714
# 5560   -16878.441938
# 651    -20290.396185
#             ...
# 57      -1240.635905
# 578    -31035.266249
# 5848    -1335.481073
# 2439    11425.789223
# 7188    -1575.988022
# Name: price, Length: 8000, dtype: float64

# %%
plt.scatter(ytrain_pred,residual)
plt.axhline(y=0,c="red")
plt.xlabel("predicted values")
plt.ylabel("Residual")
plt.title('Residual Plot: Residuals vs Predicted Values')
plt.show()

# %%
plt.boxplot(residual)
plt.ylabel("Residuals")
plt.show()

# %%
plt.hist(residual,density=True)
plt.show()
